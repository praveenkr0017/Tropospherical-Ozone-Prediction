# %%
import pandas as pd
import numpy as np
# df = pd.read_csv('/content/CAMS+ERA5_Total_Final_Combined_Data_Banda.csv')
#df = pd.read_csv('/content/combined__.csv')
# df = pd.read_csv('/content/Final.csv')
df = pd.read_csv('Final.csv')

# %%
df.head()
# Out:
#    longitude  latitude              time            co           no2  \
# 0      80.25     25.35  01-02-2003 00:00  9.770000e-07  1.090000e-08
# 1      80.25     25.35  01-02-2003 03:00  8.850000e-07  5.560000e-09
# 2      80.25     25.35  01-02-2003 06:00  5.290000e-07  7.370000e-10
# 3      80.25     25.35  01-02-2003 09:00  4.860000e-07  7.610000e-10
# 4      80.25     25.35  01-02-2003 12:00  5.410000e-07  2.370000e-09
#
#            hcho            no           so2           go3  pressure_level  \
# 0  2.550000e-09  3.560000e-10  5.620000e-09  2.250000e-08            1000
# 1  2.810000e-09  7.210000e-10  3.120000e-09  4.170000e-08            1000
# 2  1.830000e-09  1.200000e-10  8.700000e-10  7.570000e-08            1000
# 3  1.560000e-09  1.190000e-10  1.160000e-09  8.220000e-08            1000
# 4  1.630000e-09  1.750000e-11  2.110000e-09  6.750000e-08            1000
#
#    number  expver         u         v         r          t         blh  \
# 0       0       1  0.437677  0.473905  86.93266  285.11010    37.72780
# 1       0       1 -1.183033  0.422198  75.06712  285.77612   790.59570
# 2       0       1 -2.180543  1.399578  64.30040  287.37817  1019.94920
# 3       0       1 -1.968803  0.046848  57.85016  289.48120  1124.46970
# 4       0       1 -2.039933 -1.509186  61.89409  288.94360   277.26074
#
#            c5h8    aod550         w
# 0  1.290000e-09  0.641847  0.028335
# 1  1.120000e-09  0.532422  0.033648
# 2  6.270000e-11  0.466126 -0.025298
# 3  5.090000e-11  0.341439 -0.042685
# 4  3.480000e-10  0.413923 -0.024899

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43824 entries, 0 to 43823
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   longitude       43824 non-null  float64
#  1   latitude        43824 non-null  float64
#  2   time            43824 non-null  object
#  3   co              43824 non-null  float64
#  4   no2             43824 non-null  float64
#  5   hcho            43824 non-null  float64
#  6   no              43824 non-null  float64
#  7   so2             43824 non-null  float64
#  8   go3             43824 non-null  float64
#  9   pressure_level  43824 non-null  int64
#  10  number          43824 non-null  int64
#  11  expver          43824 non-null  int64
#  12  u               43824 non-null  float64
#  13  v               43824 non-null  float64
#  14  r               43824 non-null  float64
#  15  t               43824 non-null  float64
#  16  blh             43824 non-null  float64
#  17  c5h8            43824 non-null  float64
#  18  aod550          43824 non-null  float64
#  19  w               43824 non-null  float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 6.7+ MB

# %%
df.shape
# Out:
# (43824, 20)

# %%
df.describe()
# Out:
#        longitude      latitude            co           no2          hcho  \
# count   43824.00  4.382400e+04  4.382400e+04  4.382400e+04  4.382400e+04
# mean       80.25  2.535000e+01  5.562349e-07  1.286303e-08  3.266812e-09
# std         0.00  1.028522e-11  4.220594e-07  1.289554e-08  1.715605e-09
# min        80.25  2.535000e+01  9.310000e-08  1.000000e-14  7.890000e-10
# 25%        80.25  2.535000e+01  2.300000e-07  2.930000e-09  2.130000e-09
# 50%        80.25  2.535000e+01  4.170000e-07  9.290000e-09  2.850000e-09
# 75%        80.25  2.535000e+01  7.700000e-07  1.910000e-08  3.870000e-09
# max        80.25  2.535000e+01  2.900000e-06  2.700000e-07  2.180000e-08
#
#                  no           so2           go3  pressure_level   number  \
# count  4.382400e+04  4.382400e+04  4.382400e+04         43824.0  43824.0
# mean   1.393271e-09  7.123028e-09  5.751217e-08          1000.0      0.0
# std    3.843911e-09  5.636454e-09  3.870685e-08             0.0      0.0
# min    0.000000e+00  0.000000e+00  1.000000e-14          1000.0      0.0
# 25%    1.060000e-10  2.650000e-09  2.760000e-08          1000.0      0.0
# 50%    1.940000e-10  5.430000e-09  5.020000e-08          1000.0      0.0
# 75%    6.840000e-10  1.020000e-08  8.620000e-08          1000.0      0.0
# max    5.460000e-08  3.530000e-08  2.150000e-07          1000.0      0.0
#
#         expver             u             v             r             t  \
# count  43824.0  43824.000000  43824.000000  43824.000000  43824.000000
# mean       1.0      0.507959     -0.235603     57.038031    301.080334
# std        0.0      2.017633      1.467451     23.452537      6.770186
# min        1.0     -8.962476     -6.770963      5.509416    277.615480
# 25%        1.0     -0.935588     -1.315110     37.834091    296.712218
# 50%        1.0      0.668269     -0.257749     58.855232    301.634770
# 75%        1.0      1.947503      0.810987     76.631568    305.405392
# max        1.0      7.529867      8.421390    100.712050    318.412100
#
#                 blh          c5h8        aod550             w
# count  43824.000000  4.382400e+04  43824.000000  43824.000000
# mean     573.746660  6.102406e-09      0.521418     -0.003917
# std      807.860647  9.399744e-09      0.304328      0.028295
# min       10.401449  3.680000e-11      0.013130     -0.228775
# 25%       59.813095  8.340000e-10      0.309280     -0.024011
# 50%      204.993750  2.860000e-09      0.458064     -0.003750
# 75%      789.274965  7.240000e-09      0.657190      0.016531
# max     5090.277300  1.580000e-07      3.855536      0.113329

# %%
df.isnull()
# Out:
#        longitude  latitude   time     co    no2   hcho     no    so2    go3  \
# 0          False     False  False  False  False  False  False  False  False
# 1          False     False  False  False  False  False  False  False  False
# 2          False     False  False  False  False  False  False  False  False
# 3          False     False  False  False  False  False  False  False  False
# 4          False     False  False  False  False  False  False  False  False
# ...          ...       ...    ...    ...    ...    ...    ...    ...    ...
# 43819      False     False  False  False  False  False  False  False  False
# 43820      False     False  False  False  False  False  False  False  False
# 43821      False     False  False  False  False  False  False  False  False
# 43822      False     False  False  False  False  False  False  False  False
# 43823      False     False  False  False  False  False  False  False  False
#
#        pressure_level  number  expver      u      v      r      t    blh  \
# 0               False   False   False  False  False  False  False  False
# 1               False   False   False  False  False  False  False  False
# 2               False   False   False  False  False  False  False  False
# 3               False   False   False  False  False  False  False  False
# 4               False   False   False  False  False  False  False  False
# ...               ...     ...     ...    ...    ...    ...    ...    ...
# 43819           False   False   False  False  False  False  False  False
# 43820           False   False   False  False  False  False  False  False
# 43821           False   False   False  False  False  False  False  False
# 43822           False   False   False  False  False  False  False  False
# 43823           False   False   False  False  False  False  False  False
#
#         c5h8  aod550      w
# 0      False   False  False
# 1      False   False  False
# 2      False   False  False
# 3      False   False  False
# 4      False   False  False
# ...      ...     ...    ...
# 43819  False   False  False
# 43820  False   False  False
# 43821  False   False  False
# 43822  False   False  False
# 43823  False   False  False
#
# [43824 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# longitude         0
# latitude          0
# time              0
# co                0
# no2               0
# hcho              0
# no                0
# so2               0
# go3               0
# pressure_level    0
# number            0
# expver            0
# u                 0
# v                 0
# r                 0
# t                 0
# blh               0
# c5h8              0
# aod550            0
# w                 0
# dtype: int64

# %%
df1 = df.drop(['longitude','latitude','pressure_level','number','expver'],axis=1) #Dropping redundant columns (features)

# %%
print(df.columns)
# Out:
# Index(['longitude', 'latitude', 'time', 'co', 'no2', 'hcho', 'no', 'so2',
#        'go3', 'pressure_level', 'number', 'expver', 'u', 'v', 'r', 't', 'blh',
#        'c5h8', 'aod550', 'w'],
#       dtype='object')

# %%
df1
# Out:
#                    time            co           no2          hcho  \
# 0      01-02-2003 00:00  9.770000e-07  1.090000e-08  2.550000e-09
# 1      01-02-2003 03:00  8.850000e-07  5.560000e-09  2.810000e-09
# 2      01-02-2003 06:00  5.290000e-07  7.370000e-10  1.830000e-09
# 3      01-02-2003 09:00  4.860000e-07  7.610000e-10  1.560000e-09
# 4      01-02-2003 12:00  5.410000e-07  2.370000e-09  1.630000e-09
# ...                 ...           ...           ...           ...
# 43819   12/31/2017 9:00  1.110000e-06  4.780000e-09  2.860000e-09
# 43820  12/31/2017 12:00  1.270000e-06  9.360000e-09  2.880000e-09
# 43821  12/31/2017 15:00  1.850000e-06  2.590000e-08  3.240000e-09
# 43822  12/31/2017 18:00  2.270000e-06  3.950000e-08  4.050000e-09
# 43823  12/31/2017 21:00  2.500000e-06  3.610000e-08  4.440000e-09
#
#                  no           so2           go3         u         v  \
# 0      3.560000e-10  5.620000e-09  2.250000e-08  0.437677  0.473905
# 1      7.210000e-10  3.120000e-09  4.170000e-08 -1.183033  0.422198
# 2      1.200000e-10  8.700000e-10  7.570000e-08 -2.180543  1.399578
# 3      1.190000e-10  1.160000e-09  8.220000e-08 -1.968803  0.046848
# 4      1.750000e-11  2.110000e-09  6.750000e-08 -2.039933 -1.509186
# ...             ...           ...           ...       ...       ...
# 43819  2.570000e-10  1.930000e-09  1.310000e-07 -0.349399 -1.497217
# 43820  7.580000e-11  5.730000e-09  7.490000e-08 -1.137336 -1.923453
# 43821  4.560000e-10  1.400000e-08  2.000000e-08 -1.372306 -1.545503
# 43822  8.900000e-10  2.110000e-08  1.080000e-08 -0.507361 -0.471777
# 43823  9.660000e-09  1.070000e-08  3.960000e-09  0.280722 -0.321939
#
#                r          t          blh          c5h8    aod550         w
# 0      86.932660  285.11010    37.727800  1.290000e-09  0.641847  0.028335
# 1      75.067120  285.77612   790.595700  1.120000e-09  0.532422  0.033648
# 2      64.300400  287.37817  1019.949200  6.270000e-11  0.466126 -0.025298
# ...            ...           ...       ...       ...           ...
# 43819   869.097900  1.140000e-10  0.570641 -0.048225  1.310000e-07
# 43820    91.926160  1.090000e-09  0.579304 -0.010833  7.490000e-08
# 43821    47.471542  2.800000e-09  0.597642 -0.015483  2.000000e-08
# 43822    17.858460  3.140000e-09  0.646755 -0.018263  1.080000e-08
# 43823    13.074355  3.610000e-09  0.685662 -0.007951  3.960000e-09
#
# [43824 rows x 15 columns]

# %% [markdown]
# Now , Here we have 8 data points for every day i.e. 8 data points in 3 hourly interval , now converting this data to daily average data for every day.

# %%
df2['datetime'] = pd.to_datetime(df2.iloc[:,0],format='mixed')  #Coverting the existing column 'time' data into pandas readable datetime format
df2['date'] = df2['datetime'].dt.date   #Extracting only the date
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12700\2132082522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['datetime'] = pd.to_datetime(df2.iloc[:,0],format='mixed')  #Coverting the existing column 'time' data into pandas readable datetime format
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12700\2132082522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] = df2['datetime'].dt.date   #Extracting only the date

# %%
df2['date']
# Out:
# 0        2003-01-02
# 1        2003-01-02
# 2        2003-01-02
# 3        2003-01-02
# 4        2003-01-02
#             ...
# 43819    2017-12-31
# 43820    2017-12-31
# 43821    2017-12-31
# 43822    2017-12-31
# 43823    2017-12-31
# Name: date, Length: 43824, dtype: object

# %%
co_col = df2.columns[1]
no2_col = df2.columns[2]
hcho_col = df2.columns[3]
no_col = df2.columns[4]
so2_col = df2.columns[5]
u_col = df2.columns[6]
v_col = df2.columns[7]
r_col =df2.columns[8]
t_col = df2.columns[9]
blh_col = df2.columns[10]
o3_col = df2.columns[11]
c5h8_col = df2.columns[12]
aod550_col = df2.columns[13]
vert_wind = df2.columns[14]

# %%
df3 = df2.groupby('date').agg({
    co_col: 'mean',  # Average of 'co'
    no2_col: 'mean',  # Average of 'no2'
    hcho_col: 'mean', # Average of 'hcho'
    no_col: 'mean',  # Average of 'no'
    so2_col: 'mean',  # Average of 'no2'
    u_col: 'mean',  # Average of 'u'
    v_col: 'mean',  # Average of 'v'
    r_col: 'mean',  # Average of 'r'
    t_col: 'mean',  # Average of 't'
    blh_col: 'mean',  # Average of 'blh'
    o3_col: 'mean',  # Average of 'o3'
    c5h8_col: 'mean', # Average of 'c5h8'
    aod550_col: 'mean', # Average of 'aod550'
    vert_wind: 'mean', # Average of 'vert_w'
}).reset_index()

# %%
df3
# Out:
#             date            co           no2          hcho            no  \
# 0     2003-01-02  7.402500e-07  5.191000e-09  2.226250e-09  1.748125e-10
# 1     2003-01-03  9.008750e-07  6.485625e-09  2.913750e-09  3.588125e-10
# 2     2003-01-04  7.522500e-07  5.176250e-09  2.098750e-09  1.651625e-10
# 3     2003-01-05  8.117500e-07  5.164875e-09  2.182500e-09  3.451375e-10
# 4     2003-01-06  8.548750e-07  5.434250e-09  2.341250e-09  7.319875e-10
# ...          ...           ...           ...           ...           ...
# 5473  2017-12-27  1.259500e-06  2.227750e-08  3.448750e-09  4.469750e-09
# 5474  2017-12-28  1.677250e-06  2.816250e-08  4.176250e-09  2.679250e-09
# 5475  2017-12-29  1.814250e-06  2.589750e-08  4.217500e-09  1.503388e-09
# 5476  2017-12-30  1.846250e-06  1.799250e-08  4.082500e-09  1.343200e-09
# 5477  2017-12-31  1.836250e-06  3.163750e-08  3.748750e-09  2.030350e-09
#
#                so2         u         v          r           t         blh  \
# 0     3.970000e-09 -1.898618 -0.304611  71.264304  286.796873  430.097927
# 1     6.491250e-09  0.469245 -1.804741  75.071473  286.960452  269.409405
# 2     5.178750e-09  2.647894 -1.226829  74.068304  286.112428  359.103796
# 3     4.932500e-09  1.054762 -0.083210  74.035942  285.816466  252.040761
# 4     3.966250e-09 -1.163326 -0.203859  81.577966  284.944824  193.752882
# ...            ...       ...       ...        ...         ...         ...
# 5473  1.376500e-08  0.666197 -0.271301  62.117762  292.366456  240.524968
# 5474  1.659125e-08 -0.121147 -0.396058  65.571665  292.101044  227.906880
# 5475  1.231750e-08 -1.061642  0.065850  69.292657  291.957276  238.063698
# 5476  9.324000e-09 -0.779244 -0.749657  75.312341  291.198365  215.496743
# 5477  7.053750e-09 -0.463425 -0.609487  80.070215  290.069916  215.762900
#
#               c5h8    aod550         w           go3
# 0     5.538250e-10  0.454326 -0.016849  5.496250e-08
# 1     5.243125e-10  0.554401 -0.019060  6.398750e-08
# 2     4.669125e-10  0.549194  0.000768  6.223750e-08
# 3     7.741875e-10  0.435245 -0.001985  6.532500e-08
# 4     1.012700e-09  0.434533 -0.022206  6.977500e-08
# ...            ...       ...       ...           ...
# 5473  2.826725e-09  0.505315 -0.002126  3.968100e-08
# 5474  2.631462e-09  0.664617 -0.010654  4.797500e-08
# 5475  1.966500e-09  0.858759 -0.016902  6.167000e-08
# 5476  1.860750e-09  0.669124 -0.017920  5.252750e-08
# 5477  2.061625e-09  0.690611 -0.014477  5.313125e-08
#
# [5478 rows x 15 columns]

# %%
df3.shape
# Out:
# (5478, 15)

# %% [markdown]
# 43824/8 = 5478 So we converted the data into daily averages data

# %% [markdown]
# Below cell's code is to convert the df3 dataframe to csv file and download this daily avarage dataset. (So run the code whenever csv file is to be downloaded)

# %%
# df3.to_csv('Daily_Average_Dataset_for_Banda.csv',index = False)
# from google.colab import files
# files.download('Daily_Average_Dataset_for_Banda.csv')

# %% [markdown]
# **Visualization**

# %%
import matplotlib.pyplot as plt

#Setting the size of the grapgh
plt.figure(figsize=(30,10))

#Plotting the graph
plt.plot(df3['date'],df3['go3'],marker = '.',linestyle='-',color='b',label='Tropospherical Ozone')

#Adding the labels
plt.xlabel('Time')
plt.ylabel('Tropospheric Ozone')
plt.title('Tropospheric Ozone variation over time 2 Jan 2003 - 31 Dec 2017')


#Show the plot
plt.show()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5478 entries, 0 to 5477
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0
columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   co      5478 non-null   float64
#  1   no2     5478 non-null   float64
#  2   hcho    5478 non-null   float64
#  3   no      5478 non-null   float64
#  4   so2     5478 non-null   float64
#  5   u       5478 non-null   float64
#  6   v       5478 non-null   float64
#  7   r       5478 non-null   float64
#  8   t       5478 non-null   float64
#  9   blh     5478 non-null   float64
#  10  c5h8    5478 non-null   float64
#  11  aod550  5478 non-null   float64
#  12  w       5478 non-null   float64
#  13  go3     5478 non-null   float64
# dtypes: float64(14)
# memory usage: 599.3 KB

# %% [markdown]
# Checking if the go3 is not correlated to a particular feature , if yes then remove it. Threshold correlation value can be anything you fill right.

# %%
df3.corr()
# Out:
#               co       no2      hcho        no       so2         u         v  \
# co      1.000000  0.619951  0.163143  0.333867  0.821474 -0.228754 -0.267869
# no2     0.619951  1.000000  0.228691  0.425923  0.603791 -0.109725 -0.131841
# hcho    0.163143  0.228691  1.000000  0.063181  0.249357 -0.166370 -0.256434
# no      0.333867  0.425923  0.063181  1.000000  0.379735 -0.106859  0.096267
# so2     0.821474  0.603791  0.249357  0.379735  1.000000 -0.185862 -0.337654
# u      -0.228754 -0.109725 -0.166370 -0.106859 -0.185862  1.000000  0.107479
# v      -0.267869 -0.131841 -0.256434  0.096267 -0.337654  0.107479  1.000000
# r       0.016479 -0.168535 -0.438468 -0.056344 -0.197561 -0.206093  0.199462
# t      -0.663309 -0.245271  0.387104 -0.060301 -0.485004  0.115553  0.135719
# blh    -0.494965 -0.268243  0.393306 -0.174289 -0.341991  0.151548 -0.039394
# c5h8   -0.114411  0.252692  0.672013  0.396539  0.017251  0.044022  0.035412
# aod550  0.160099 -0.018475  0.182154 -0.068066  0.032898 -0.091053 -0.095949
# w      -0.343697 -0.162738 -0.286511 -0.033127 -0.354880  0.792845  0.624929
# go3    -0.032433 -0.157715  0.571508 -0.289576  0.064896 -0.159962 -0.394871
#
#                r         t       blh      c5h8    aod550         w       go3
# co      0.016479 -0.663309 -0.494965 -0.114411  0.160099 -0.343697 -0.032433
# no2    -0.168535 -0.245271 -0.268243  0.252692 -0.018475 -0.162738 -0.157715
# hcho   -0.438468  0.387104  0.393306  0.672013  0.182154 -0.286511  0.571508
# no     -0.056344 -0.060301 -0.174289  0.396539 -0.068066 -0.033127 -0.289576
# so2    -0.197561 -0.485004 -0.341991  0.017251  0.032898 -0.354880  0.064896
# u      -0.206093  0.115553  0.151548  0.044022 -0.091053  0.792845 -0.159962
# v       0.199462  0.135719 -0.039394  0.035412 -0.095949  0.624929 -0.394871
# r       1.000000 -0.463695 -0.639295 -0.521778  0.269277  0.012461 -0.502074
# t      -0.463695  1.000000  0.790130  0.559808 -0.037372  0.164397  0.332388
# blh    -0.639295  0.790130  1.000000  0.450533 -0.022298  0.067261  0.526290
# c5h8   -0.521778  0.559808  0.450533  1.000000 -0.098049  0.036725  0.183241
# aod550  0.269277 -0.037372 -0.022298 -0.098049  1.000000 -0.111870  0.124602
# w       0.012461  0.164397  0.067261  0.036725 -0.111870  1.000000 -0.369877
# go3    -0.502074  0.332388  0.526290  0.183241  0.124602 -0.369877  1.000000

# %%
#Tried removing outliers but didn't work out
# from scipy import stats

# z_scores = np.abs(stats.zscore(df3))
# df_clean = df3[(z_scores < 2).all(axis=1)]
# df_clean

# %%
#Tried plotting the go3 once outliers got removed from the data

# # Visualising y_test (actual) vs y_log_pred (predicted)


# #Setting the ratio of the figure
# plt.figure(figsize=(15,6))

# #Plotting actual values curve
# plt.plot(df_clean['go3'], label = "Log of Actual", marker = "o", color = "b")

# plt.xlabel('Sample Index')
# plt.ylabel('log of Ozone (go3) Level')
# plt.title('log of Actual vs log of Predicted Ozone Levels')

# # Add a legend to distinguish between actual and predicted
# plt.legend()

# # Show the plot
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Feature Engineering
#
#
# *   Adding new feature i.e. wind horizontal speed (wind_hor_v) using the two horizontal components of wind i.e. u and v . This new feature can be more useful.

# %%
df4 = df3  # Creating a new dataframe df4 as copy of df3
# df4['wind_hor_v'] = np.sqrt(df3['u']**2 + df3['v']**2 + df3['w']**2)
df4['Hor_wind_magnitude'] = np.sqrt(df3['u']**2 + df3['v']**2)

# %%
df4
# Out:
#                 co           no2          hcho            no           so2  \
# 0     7.402500e-07  5.191000e-09  2.226250e-09  1.748125e-10  3.970000e-09
# 1     9.008750e-07  6.485625e-09  2.913750e-09  3.588125e-10  6.491250e-09
# 2     7.522500e-07  5.176250e-09  2.098750e-09  1.651625e-10  5.178750e-09
# 3     8.117500e-07  5.164875e-09  2.182500e-09  3.451375e-10  4.932500e-09
# 4     8.548750e-07  5.434250e-09  2.341250e-09  7.319875e-10  3.966250e-09
# ...            ...           ...           ...           ...           ...
# 5473  1.259500e-06  2.227750e-08  3.448750e-09  4.469750e-09  1.376500e-08
# 5474  1.677250e-06  2.816250e-08  4.176250e-09  2.679250e-09  1.659125e-08
# 5475  1.814250e-06  2.589750e-08  4.217500e-09  1.503388e-09  1.231750e-08
# 5476  1.846250e-06  1.799250e-08  4.082500e-09  1.343200e-09  9.324000e-09
# 5477  1.836250e-06  3.163750e-08  3.748750e-09  2.030350e-09  7.053750e-09
#
#              u         v          r           t         blh          c5h8  \
# 0    -1.898618 -0.304611  71.264304  286.796873  430.097927  5.538250e-10
# 1     0.469245 -1.804741  75.071473  286.960452  269.409405  5.243125e-10
# 2     2.647894 -1.226829  74.068304  286.112428  359.103796  4.669125e-10
# 3     1.054762 -0.083210  74.035942  285.816466  252.040761  7.741875e-10
# 4    -1.163326 -0.203859  81.577966  284.944824  193.752882  1.012700e-09
# ...        ...       ...        ...         ...         ...           ...
# 5473  0.666197 -0.271301  62.117762  292.366456  240.524968  2.826725e-09
# 5474 -0.121147 -0.396058  65.571665  292.101044  227.906880  2.631462e-09
# 5475 -1.061642  0.065850  69.292657  291.957276  238.063698  1.966500e-09
# 5476 -0.779244 -0.749657  75.312341  291.198365  215.496743  1.860750e-09
# 5477 -0.463425 -0.609487  80.070215  290.069916  215.762900  2.061625e-09
#
#         aod550         w           go3  Hor_wind_magnitude
# 0     0.454326 -0.016849  5.496250e-08            1.922898
# 5475  0.858759 -0.016902  6.167000e-08            1.063682
# 5476  0.669124 -0.017920  5.252750e-08            1.081299
# 5477  0.690611 -0.014477  5.313125e-08            0.765661
#
#       Hor_wind_direction    log_go3
# 0              80.885249 -16.716615
# 1             345.425405 -16.564578
# 2             294.859355 -16.592308
# 3             274.510718 -16.543891
# 4              80.060509 -16.477990
# ...                  ...        ...
# 5473          292.158006 -17.042393
# 5474           17.007947 -16.852586
# 5475           93.549326 -16.601468
# 5476           46.108626 -16.761929
# 5477           37.247624 -16.750501
#
# [5478 rows x 17 columns]

# %% [markdown]
# Obervation : correlation value of go3 with every feature is even less than 0.5 so no issue , no need to remove any feature on this basis.

# %%
#Vizualisation of correlation of features

import seaborn as sns

# Plot correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df4.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
df4 = df4.drop(['u','v'],axis = 1) # Dropping u and v as we can see that wind_hor_v is of more importance than u and v

# %%
df4
# Out:
#                 co           no2          hcho            no           so2  \
# 0     7.402500e-07  5.191000e-09  2.226250e-09  1.748125e-10  3.970000e-09
# 1     9.008750e-07  6.485625e-09  2.913750e-09  3.588125e-10  6.491250e-09
# 2     7.522500e-07  5.176250e-09  2.098750e-09  1.651625e-10  5.178750e-09
# 3     8.117500e-07  5.164875e-09  2.182500e-09  3.451375e-10  4.932500e-09
# 4     8.548750e-07  5.434250e-09  2.341250e-09  7.319875e-10  3.966250e-09
# ...            ...           ...           ...           ...           ...
# 5473  1.259500e-06  2.227750e-08  3.448750e-09  4.469750e-09  1.376500e-08
# 5474  1.677250e-06  2.816250e-08  4.176250e-09  2.679250e-09  1.659125e-08
# 5475  1.814250e-06  2.589750e-08  4.217500e-09  1.503388e-09  1.231750e-08
# 5476  1.846250e-06  1.799250e-08  4.082500e-09  1.343200e-09  9.324000e-09
# 5477  1.836250e-06  3.163750e-08  3.748750e-09  2.030350e-09  7.053750e-09
#
#               r           t         blh          c5h8    aod550         w  \
# 0     71.264304  286.796873  430.097927  5.538250e-10  0.454326 -0.016849
# 1     75.071473  286.960452  269.409405  5.243125e-10  0.554401 -0.019060
# 2     74.068304  286.112428  359.103796  4.669125e-10  0.549194  0.000768
# 3     74.035942  285.816466  252.040761  7.741875e-10  0.435245 -0.001985
# 4     81.577966  284.944824  193.752882  1.012700e-09  0.434533 -0.022206
# ...         ...         ...         ...           ...       ...       ...
# 5473  62.117762  292.366456  240.524968  2.826725e-09  0.505315 -0.002126
# 5474  65.571665  292.101044  227.906880  2.631462e-09  0.664617 -0.010654
# 5475  69.292657  291.957276  238.063698  1.966500e-09  0.858759 -0.016902
# 5476  75.312341  291.198365  215.496743  1.860750e-09  0.669124 -0.017920
# 5477  80.070215  290.069916  215.762900  2.061625e-09  0.690611 -0.014477
#
#                go3  Hor_wind_magnitude  Hor_wind_direction    log_go3
# 0     5.496250e-08            1.922898           80.885249 -16.716615
# 1     6.398750e-08            1.864747          345.425405 -16.564578
# 5475            1.063682           93.549326 -16.601468
# 5476            1.081299           46.108626 -16.761929
# 5477            0.765661           37.247624 -16.750501
#
# [5478 rows x 14 columns]

# %% [markdown]
# Renaming the variables correctly

# %%
# df4['CO'] = df4['co']
# df4['NO2'] = df4['no2']
# df4['CH2O'] = df4['hcho']
# df4['NO'] = df4['no']
# df4['SO2'] = df4['so2']
# df4['R.H.'] = df4['r']
# df4['Temp'] = df4['t']
# df4['BLH'] = df4['blh']
# df4['C5H8'] = df4['c5h8']
# df4['AOD550'] = df4['aod550']
df4.rename(columns={'co': 'CO','no2':'NO2','hcho':'CH2O','no':'NO','so2':'SO2','r':'R.H.','t':'Temp','blh':'BLH','c5h8':'C5H8','aod550':'AOD550','w':'Vert_wind_magnitude'}, inplace=True)

# %% [markdown]
# Data Preprocessing End

# %% [markdown]
# *** Random Forest Model ***

# %% [markdown]
# Scaling / Normalization of features and getting the scaled dataframe

# %%
from sklearn.model_selection import train_test_split

# Scaling or Normalising of features

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() # or use MinMaxScaler() if preferred

#X = df3.drop('go3', axis=1)
X = df4.drop('log_go3', axis=1)
X_scaled = scaler.fit_transform(X) # Scaling of features is done so that all features are normalised , so that while calculating feature importance no problem occurs.
# Convert the scaled array back to a DataFrame with the original column names
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)


#y = df3['go3']  #Target variable
y = df4['log_go3']  #Target variable

# If you want to add back the target variable 'go3' to this scaled DataFrame
#df_scaled = pd.concat([X_scaled_df, df3['go3']], axis=1)
df_scaled = pd.concat([X_scaled_df, df4['log_go3']], axis=1)

# %%
df_scaled
# Out:
#             CO       NO2      CH2O        NO       SO2      R.H.      Temp  \
# 0     0.532380 -1.322562 -1.041610 -0.636225 -0.791249  0.714175 -2.262562
# 1     0.997090 -1.099384 -0.353417 -0.540149 -0.158544  0.905299 -2.236651
# 2     0.567098 -1.325104 -1.169239 -0.641264 -0.487915  0.854939 -2.370981
# 3     0.739239 -1.327065 -1.085404 -0.547289 -0.549711  0.853315 -2.417863
# 4     0.864006 -1.280628 -0.926494 -0.345293 -0.792190  1.231933 -2.555935
# ...        ...       ...       ...       ...       ...       ...       ...
# 5473  2.034640  1.622937  0.182122  1.606402  1.666796  0.255008 -1.380316
# 5474  3.243247  2.637437  0.910355  0.671482  2.376041  0.428398 -1.422359
# 5475  3.639606  2.246979  0.951646  0.057498  1.303548  0.615196 -1.445132
# 5476  3.732187  0.884256  0.816510 -0.026145  0.552332  0.917391 -1.565347
# 5477  3.703255  3.236483  0.482424  0.332655 -0.017385  1.156242 -1.744098
#
#            BLH      C5H8    AOD550  Vert_wind_magnitude  Hor_wind_magnitude  \
# 0    -0.446778 -1.011637 -0.235606            -0.755151            0.097547
# 1    -0.946553 -1.017018  0.115826            -0.884280            0.040487
# 2    -0.667584 -1.027484  0.097543             0.273599            1.074274
# 3    -1.000573 -0.971460 -0.302613             0.112853           -0.751089
# 4    -1.181860 -0.927974 -0.305114            -1.067990           -0.630383
# ...        ...       ...       ...                  ...                 ...
# 5473 -1.036389 -0.597234 -0.056549             0.104592           -1.083453
# 5474 -1.075634 -0.632835  0.502871            -0.393407           -1.382878
# 5475 -1.044044 -0.754073  1.184640            -0.758246           -0.745552
# 5476 -1.114232 -0.773354  0.518700            -0.817698           -0.728265
# 5477 -1.113405 -0.736730  0.594156            -0.616642           -1.037982
#
#       Hor_wind_direction    log_go3
# 0              -1.144354 -16.716615
# 1               1.366071 -16.564578
# 2               0.886211 -16.592308
# 3               0.693107 -16.543891
# 4              -1.152181 -16.477990
# ...                  ...        ...
# 5473            0.860576 -17.042393
# 5474           -1.750535 -16.852586
# 5475           -1.024175 -16.601468
# 5476           -1.474376 -16.761929
# 5477           -1.558465 -16.750501
#
# [5478 rows x 14 columns]

# %%
X = df_scaled.drop('log_go3', axis=1)

y = df_scaled['log_go3']  #Target variable

# %% [markdown]
# Now, Splitting of data into testing and training data and making the model learn.

# %%
#Data Splitting in train:test = 80:20 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor  #Random forest Regressor is used because O3 has continous numerical values and not labels pr categories else RandomeForestClassifier would have been used.

#Training the random forest regression model
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Predict and evaluate
y_log_pred = rf.predict(X_test)

# %%
y_log_pred
# Out:
# array([-16.59673089, -16.77382093, -16.57209335, ..., -16.86626412,
#        -16.48112321, -16.51963814])

# %%
type(y_log_pred)
# Out:
# numpy.ndarray

# %%
y_log_pred.shape  #1096 because 5478 is total rows and 20% of it is 1095.6 ~ 1096
# Out:
# (1644,)

# %%
print(len(y_log_pred)) #len function works as it is array type
# Out:
# 1644

# %%
y_log_pred_df = pd.DataFrame(y_log_pred) # Here we convertef the y_pred array into a dataframe containing single column for our convinience

# %%
type(y_log_pred_df)
# Out:
# pandas.core.frame.DataFrame

# %%
y_log_pred_df.shape
# Out:
# (1644, 1)

# %% [markdown]
# Performace check of RF Model

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

#Calculation of mean square error of predicted O3 level with actual
mse = mean_squared_error(y_test, y_log_pred)

#Calculation of r2 score of predicted O3 level with actual
r2 = r2_score(y_test, y_log_pred)

#Calculation of Mean Absolute Error of predicted O3 level with actual
mae = mean_absolute_error(y_test, y_log_pred)

# %%
print("Mean Sqaure Error  : ", mse)
print("r2 score           : ", r2)
print("Mean Absolute Erro : ", mae)
# Out:
# Mean Sqaure Error  :  0.013466496512413712
# r2 score           :  0.7854344242786824
# Mean Absolute Erro :  0.09031513784773074

# %%
# Visualising y_test (actual) vs y_log_pred (predicted)


#Setting the ratio of the figure
plt.figure(figsize=(15,6))

#Plotting actual values curve
plt.plot(y_test.values, label = "Log of Actual", marker = "o", color = "b")

#Plotting predicted values curve
plt.plot(y_log_pred_df.values, label = "Log of Predicted", marker = "x", color = "r")

plt.xlabel('Sample Index')
plt.ylabel('log of Ozone (go3) Level')
plt.title('log of Actual vs log of Predicted Ozone Levels')

# Add a legend to distinguish between actual and predicted
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Calculation of mean square error of predicted O3 level with actual
mseActual = mean_squared_error(np.exp(y_test), np.exp(y_log_pred))

#Calculation of r2 score of predicted O3 level with actual
r2Actual = r2_score(np.exp(y_test), np.exp(y_log_pred))

#Calculation of Mean Absolute Error of predicted O3 level with actual  np.log(df4['go3'])
maeActual = mean_absolute_error(np.exp(y_test), np.exp(y_log_pred))

# %%
print("Mean Sqaure Error  : ", mseActual)
print("r2 score           : ", r2Actual)
print("Mean Absolute Erro : ", maeActual)
# Out:
# Mean Sqaure Error  :  4.425826126955084e-17
# r2 score           :  0.7937325112539717
# Mean Absolute Erro :  5.087143458615212e-09

# %%
y_pred_df = pd.DataFrame(np.exp(y_log_pred)) # Here we converted the y_log_pred array into a dataframe containing single column of exponential of y_log_pred for our convinience

# %%
# Visualising y_test (actual) vs y__pred (predicted)


#Setting the ratio of the figure
plt.figure(figsize=(15,6))

#Plotting actual values curve
plt.plot(np.exp(y_test).values, label = "Actual", marker = "o", color = "b")

#Plotting predicted values curve
plt.plot(y_pred_df.values, label = "Predicted", marker = "x", color = "r")

plt.xlabel('Sample Index')
plt.ylabel('Ozone (go3) Level')
plt.title('go3 Actual vs Predicted Ozone Levels')

# Add a legend to distinguish between actual and predicted
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Implementing Feature Importance Schemes***
#
# ---

# %% [markdown]
# *   Built-in Feature importance scheme of RF model i.e. Gini Importncae scheme

# %%
#Getting feature importance
importances = rf.feature_importances_

#Creating a Dataframe for better vizualisation
feature_names = X_train.columns
feature_importances = pd.DataFrame({'Feature' : feature_names,'Importance' : importances})

#Sorting the features as per their importance
feature_importances = feature_importances.sort_values(by='Importance', ascending = False)

#Displaying the top features
feature_importances
# Out:
#                 Feature  Importance
# 7                   BLH    0.302560
# 2                  CH2O    0.137231
# 3                    NO    0.131596
# 10  Vert_wind_magnitude    0.076983
# 0                    CO    0.076851
# 5                  R.H.    0.059828
# 4                   SO2    0.046445
# 1                   NO2    0.035620
# 12   Hor_wind_direction    0.033728
# 8                  C5H8    0.029191
# 6                  Temp    0.026111
# 11   Hor_wind_magnitude    0.022656
# 9                AOD550    0.021201

# %%
#Visualizing feature vs importance

import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances)
plt.title('Feature Importance in Random Forest as per Gini Importance')
plt.tight_layout()
plt.show()

# %% [markdown]
# *   Permutation based importance scheme

# %%
from sklearn.inspection import permutation_importance

# #Calculating feature importance on test data
# result = permutation_importance(rf,X_test, y_test, n_repeats = 10, random_state = 42)

# #Getting thr sorted features on the basis of their importance
# sorted_idx = result.importances_mean.argsort()

# # Plot the results
# plt.figure(figsize=(10, 6))
# plt.barh(X_test.columns[sorted_idx], result.importances_mean[sorted_idx])
# plt.xlabel('Permutation Importance')
# plt.title('Permutation-Based Feature Importance')
# plt.show()

# %%
# Perform Permutation Importance
result = permutation_importance(rf, X_test, y_test, n_repeats=10, random_state=42, n_jobs=-1)

# Display the importance results
importance_scores = result.importances_mean
feature_names = X_test.columns

# Print sorted feature importances
print("Permutation-Based Feature Importances:")
for i in importance_scores.argsort()[::-1]:  # Sort in descending order
    print(f"{feature_names[i]}: {importance_scores[i]:.4f}")
# Out:
# Permutation-Based Feature Importances:
# NO: 0.2444
# CH2O: 0.2356
# BLH: 0.2100
# CO: 0.1486
# R.H.: 0.0710
# Vert_wind_magnitude: 0.0656
# SO2: 0.0461
# NO2: 0.0405
# C5H8: 0.0216
# Temp: 0.0151
# Hor_wind_magnitude: 0.0137
# Hor_wind_direction: 0.0096
# AOD550: 0.0069

# %%
from sklearn.inspection import permutation_importance

# Calculate permutation importance on the test set
result = permutation_importance(rf, X_test, y_test, n_repeats=10, random_state=42)  #One more optional parameter can be added i.e. scoring='accuracy'

# result.importances_mean gives the mean importance for each feature
# result.importances_std gives the standard deviation of importance

# Create a DataFrame for better visualization
feature_importances_perm = pd.DataFrame({
    'Feature': X_test.columns,
    'Importance': result.importances_mean,
    'Std Dev': result.importances_std
})

# Sort by importance
feature_importances_perm = feature_importances_perm.sort_values(by='Importance', ascending=False)

# Display the results
print(feature_importances_perm)
# Out:
#                 Feature  Importance   Std Dev
# 3                    NO    0.244415  0.011556
# 2                  CH2O    0.235570  0.008681
# 7                   BLH    0.209980  0.006900
# 0                    CO    0.148618  0.006721
# 5                  R.H.    0.071044  0.002702
# 10  Vert_wind_magnitude    0.065646  0.002993
# 4                   SO2    0.046124  0.004094
# 1                   NO2    0.040518  0.002816
# 8                  C5H8    0.021570  0.001364
# 6                  Temp    0.015127  0.001896
# 11   Hor_wind_magnitude    0.013729  0.001568
# 12   Hor_wind_direction    0.009617  0.001232
# 9                AOD550    0.006853  0.000775

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot permutation-based feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances_perm)
plt.title('Permutation-Based Feature Importance')
plt.show()

# %%
# Set a threshold for feature importance (e.g., importance > 0.01)
threshold = 0.001
important_features_perm = feature_importances_perm[feature_importances_perm['Importance'] > threshold]['Feature']

# Filter the data based on important features
X_train_filtered = X_train[important_features_perm]
X_test_filtered = X_test[important_features_perm]

# Train a new model with filtered features
rf_filtered = RandomForestRegressor(n_estimators=100, random_state=42)
rf_filtered.fit(X_train_filtered, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict and evaluate
y_pred_filtered = rf_filtered.predict(X_test_filtered)

# %%
#Calculation mean square error of predicted O3 level with actual
mse_filtered = mean_squared_error(y_test, y_pred_filtered)

#Calculation r2 score of predicted O3 level with actual
r2_filtered = r2_score(y_test, y_pred_filtered)

# %%
print("Mean Sqaure Error : ", mse_filtered)
print("r2 score : ", r2_filtered)
# Out:
# Mean Sqaure Error :  0.01340944026144867
# r2 score :  0.7863435179932599

# %% [markdown]
# *   Mean Decrease Accuracy Feature Importance scheme

# %%
from sklearn.inspection import permutation_importance
import numpy as np

# Perform permutation importance on the trained model
result = permutation_importance(rf, X_test, y_test, n_repeats=10, random_state=42, n_jobs=-1)

# Get feature importances
importance_scores = result.importances_mean

# Get the feature names
feature_names = X_test.columns

# Sort features by importance
indices = np.argsort(importance_scores)[::-1]  # Sort in descending order

# Print the feature importance scores
print("Feature Importances (Mean Decrease Accuracy):")
for i in indices:
    print(f"{feature_names[i]}: {importance_scores[i]:.4f}")
# Out:
# Feature Importances (Mean Decrease Accuracy):
# NO: 0.2444
# CH2O: 0.2356
# BLH: 0.2100
# CO: 0.1486
# R.H.: 0.0710
# Vert_wind_magnitude: 0.0656
# SO2: 0.0461
# NO2: 0.0405
# C5H8: 0.0216
# Temp: 0.0151
# Hor_wind_magnitude: 0.0137
# Hor_wind_direction: 0.0096
# AOD550: 0.0069

# %%
import matplotlib.pyplot as plt

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_names[indices], importance_scores[indices], color='skyblue')
plt.xlabel('Mean Decrease Accuracy')
plt.title('Feature Importance (Permutation Importance)')
plt.gca().invert_yaxis()  # To display the most important feature at the top
plt.show()

# %% [markdown]
# *   SHAP importance scheme

# %%
# !pip install shap

# %%
import shap

# Create a SHAP explainer for your RandomForestRegressor model
explainer = shap.TreeExplainer(rf)

# Calculate SHAP values for the test data
shap_values = explainer.shap_values(X_test)

# Plot summary of feature importance based on SHAP values
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %%
# Plot SHAP values for a single sample (e.g., the first sample in the test set)
shap.force_plot(explainer.expected_value, shap_values[0], X_test.iloc[0])
# Out:
# <div id='iX4A8WDJI9U2ME5ICKYQ7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -16.703684822389953, "outValue": -16.59673089240799, "link": "identity", "featureNames": ["CO", "NO2", "CH2O", "NO", "SO2", "R.H.", "Temp", "BLH", "C5H8", "AOD550", "Vert_wind_magnitude", "Hor_wind_magnitude", "Hor_wind_direction"], "features": {"0": {"effect": 0.0014133711417633774, "value": -0.9029757898923468}, "1": {"effect": 0.025997614512209413, "value": -1.2132678831709127}, "2": {"effect": -0.10577950565691537, "value": -0.7125289812933918}, "3": {"effect": 0.034610308946139, "value": -0.5873515610806346}, "4": {"effect": 0.0009142483119459261, "value": -0.6193491036758042}, "5": {"effect": -0.06877623868887038, "value": 0.6881715800766749}, "6": {"effect": 0.0005286881753235811, "value": 0.40588022446322397}, "7": {"effect": 0.1307195150373552, "value": 1.1131375321573493}, "8": {"effect": 0.01725653195897339, "value": -0.9297649785405895}, "9": {"effect": -0.005764204905384648, "value": -0.6607233190338557}, "10": {"effect": 0.06116363756457571, "value": -1.9581990341555537}, "11": {"effect": 0.009044221839564482, "value": 2.30810728218901}, "12": {"effect": 0.005625741745281706, "value": -1.202762314488868}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iX4A8WDJI9U2ME5ICKYQ7')
#   );
# </script>

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# ***Application of XgBoost Model***
#
#
# ---

# %%
#Data Splitting in train:test = 80:20 ratio
X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(n_estimators=500,learning_rate=0.01, random_state=42,max_depth=10)
xgb.fit(X_train_xgb, y_train_xgb)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Predict and evaluate
y_log_pred_xgb = xgb.predict(X_test_xgb)

# %%
y_log_pred_xgb.shape
# Out:
# (1644,)

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_rgb = r2_score(y_test_xgb, y_log_pred_xgb)
print("r2_score",r2_rgb)
# Out:
# r2_score 0.7819309595535338

# %%
# Visualising y_test (actual) vs y_log_pred (predicted)


#Setting the ratio of the figure
plt.figure(figsize=(15,6))

#Plotting actual values curve
plt.plot(y_test_xgb.values, label = "Log of Actual", marker = "o", color = "b")

#Plotting predicted values curve
plt.plot(y_log_pred_df.values, label = "Log of Predicted", marker = "x", color = "r")

plt.xlabel('Sample Index')
plt.ylabel('log of Ozone (go3) Level')
plt.title('log of Actual vs log of Predicted Ozone Levels')

# Add a legend to distinguish between actual and predicted
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
#Calculation of mean square error of predicted O3 level with actual
mseActual_xgb = mean_squared_error(np.exp(y_test_xgb), np.exp(y_log_pred_xgb))

#Calculation of r2 score of predicted O3 level with actual
r2Actual_xgb = r2_score(np.exp(y_test_xgb), np.exp(y_log_pred_xgb))

#Calculation of Mean Absolute Error of predicted O3 level with actual  np.log(df4['go3'])
maeActual_xgb = mean_absolute_error(np.exp(y_test_xgb), np.exp(y_log_pred_xgb))

# %%
print("Mean Sqaure Error  : ", mseActual_xgb)
print("r2 score           : ", r2Actual_xgb)
print("Mean Absolute Erro : ", maeActual_xgb)
# Out:
# Mean Sqaure Error  :  4.5383946954423645e-17
# r2 score           :  0.7884862057581024
# Mean Absolute Erro :  5.111442106733119e-09

# %%
y_pred_df_xgb = pd.DataFrame(np.exp(y_log_pred_xgb)) # Here we converted the y_log_pred array into a dataframe containing single column of exponential of y_log_pred for our convinience

# %%
# Visualising y_test_xgb (actual) vs y__pred_xgb (predicted)


#Setting the ratio of the figure
plt.figure(figsize=(15,6))

#Plotting actual values curve
plt.plot(np.exp(y_test_xgb).values, label = "Actual", marker = "o", color = "b")

#Plotting predicted values curve
plt.plot(y_pred_df_xgb.values, label = "Predicted", marker = "x", color = "r")

plt.xlabel('Sample Index')
plt.ylabel('Ozone (go3) Level')
plt.title('go3 Actual vs Predicted Ozone Levels')

# Add a legend to distinguish between actual and predicted
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# *Implementing Feature Importance Schemes for XgBoost*
#
# ---

# %%
import matplotlib.pyplot as plt
from xgboost import plot_importance
# Plot feature importance
plt.figure(figsize=(10, 8))
plot_importance(xgb, importance_type='gain')  # You can use 'weight', 'gain', 'cover'
plt.show()

# %%
from sklearn.inspection import permutation_importance

# Calculate permutation importance on the test set
result_xgb = permutation_importance(xgb, X_test_xgb, y_test_xgb, n_repeats=10, random_state=42)  #One more optional parameter can be added i.e. scoring='accuracy'

# result.importances_mean gives the mean importance for each feature
# result.importances_std gives the standard deviation of importance

# Create a DataFrame for better visualization
feature_importances_perm_xgb = pd.DataFrame({
    'Feature': X_test_xgb.columns,
    'Importance': result_xgb.importances_mean,
    'Std Dev': result_xgb.importances_std
})

# Sort by importance
feature_importances_perm_xgb = feature_importances_perm_xgb.sort_values(by='Importance', ascending=False)

# Display the results
print(feature_importances_perm_xgb)
# Out:
#                 Feature  Importance   Std Dev
# 2                  CH2O    0.260459  0.011187
# 3                    NO    0.206637  0.008503
# 7                   BLH    0.177576  0.005319
# 0                    CO    0.168171  0.004081
# 5                  R.H.    0.100427  0.003296
# 10  Vert_wind_magnitude    0.054391  0.004043
# 4                   SO2    0.049462  0.003658
# 1                   NO2    0.043666  0.002923
# 8                  C5H8    0.033462  0.001936
# 6                  Temp    0.025896  0.002870
# 11   Hor_wind_magnitude    0.019315  0.002592
# 12   Hor_wind_direction    0.013041  0.001395
# 9                AOD550    0.010313  0.001160

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot permutation-based feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importances_perm_xgb)
plt.title('Permutation-Based Feature Importance')
plt.show()

# %%
# #Permutation Importance Schemes

# from sklearn.inspection import permutation_importance

# # Fit the modelimport matplotlib.pyplot as plt
# import seaborn as sns

# # Plot permutation-based feature importance
# plt.figure(figsize=(10, 6))
# sns.barplot(x='importance', y='Feature', data=feature_importances_perm)
# plt.title('Permutation-Based Feature Importance')
# plt.show()

# xgb.fit(X_train_xgb, y_train_xgb)

# # Get permutation importance
# result = permutation_importance(xgb, X_test_xgb, y_test_xgb, n_repeats=10, random_state=42)

# # Display permutation importance
# for i in result.importances_mean.argsort()[::-1]:
#     if result.importances_mean[i] - 2 * result.importances_std[i] > 0:
#         print(f"{X_train_xgb.columns[i]}: {result.importances_mean[i]:.4f} ± {result.importances_std[i]:.4f}")

# # Optional: Plot the results
# plt.barh(X_train_xgb.columns, result.importances_mean)
# plt.xlabel("Mean Decrease in Accuracy")
# plt.show()

# %% [markdown]
# SHAP Importance Scheme

# %%
import shap

# Create SHAP explainer
explainer = shap.Explainer(xgb)

# Calculate SHAP values for the test set
shap_values = explainer.shap_values(X_test_xgb)

# Plot SHAP summary plot
shap.summary_plot(shap_values, X_test_xgb)

# %%
shap.summary_plot(shap_values, X_test_xgb, plot_type="bar")

# %%
#X = X.drop('C5H8', axis=1) #,'r','so2','t','wind_hor_v']
X = X.drop('AOD550', axis=1) #,'r','so2','t','wind_hor_v']
#X = X.drop('SO2', axis=1) #,'r','so2','t','wind_hor_v']
X = X.drop('Temp', axis=1) #,'r','so2','t','wind_hor_v']
X = X.drop('Hor_wind_magnitude', axis=1) #,'r','so2','t','wind_hor_v']


#Data Splitting in train:test = 80:20 ratio
X_train_xgb1, X_test_xgb1, y_train_xgb1, y_test_xgb1 = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X
# Out:
#             CO       NO2      CH2O        NO       SO2      R.H.       BLH  \
# 0     0.532380 -1.322562 -1.041610 -0.636225 -0.791249  0.714175 -0.446778
# 1     0.997090 -1.099384 -0.353417 -0.540149 -0.158544  0.905299 -0.946553
# 2     0.567098 -1.325104 -1.169239 -0.641264 -0.487915  0.854939 -0.667584
# 3     0.739239 -1.327065 -1.085404 -0.547289 -0.549711  0.853315 -1.000573
# 4     0.864006 -1.280628 -0.926494 -0.345293 -0.792190  1.231933 -1.181860
# ...        ...       ...       ...       ...       ...       ...       ...
# 5473  2.034640  1.622937  0.182122  1.606402  1.666796  0.255008 -1.036389
# 5474  3.243247  2.637437  0.910355  0.671482  2.376041  0.428398 -1.075634
# 5475  3.639606  2.246979  0.951646  0.057498  1.303548  0.615196 -1.044044
# 5476  3.732187  0.884256  0.816510 -0.026145  0.552332  0.917391 -1.114232
# 5477  3.703255  3.236483  0.482424  0.332655 -0.017385  1.156242 -1.113405
#
#           C5H8  Vert_wind_magnitude  Hor_wind_direction
# 0    -1.011637            -0.755151           -1.144354
# 1    -1.017018            -0.884280            1.366071
# 2    -1.027484             0.273599            0.886211
# 3    -0.971460             0.112853            0.693107
# 4    -0.927974            -1.067990           -1.152181
# ...        ...                  ...                 ...
# 5473 -0.597234             0.104592            0.860576
# 5474 -0.632835            -0.393407           -1.750535
# 5475 -0.754073            -0.758246           -1.024175
# 5476 -0.773354            -0.817698           -1.474376
# 5477 -0.736730            -0.616642           -1.558465
#
# [5478 rows x 10 columns]

# %%
xgb1 = XGBRegressor(n_estimators=500,learning_rate=0.01, random_state=42,max_depth=10)
xgb1.fit(X_train_xgb1, y_train_xgb1)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Predict and evaluate
y_log_pred_xgb1 = xgb1.predict(X_test_xgb1)

# %%
y_log_pred_xgb1.shape
# Out:
# (1644,)

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_xgb1 = r2_score(y_test_xgb1, y_log_pred_xgb1)
print("r2_score1",r2_xgb1)
# Out:
# r2_score1 0.7746308945355902

# %%
#Calculation of mean square error of predicted O3 level with actual
mseActual_xgb1 = mean_squared_error(np.exp(y_test_xgb1), np.exp(y_log_pred_xgb1))

#Calculation of r2 score of predicted O3 level with actual
r2Actual_xgb1 = r2_score(np.exp(y_test_xgb1), np.exp(y_log_pred_xgb1))

#Calculation of Mean Absolute Error of predicted O3 level with actual  np.log(df4['go3'])
maeActual_xgb1 = mean_absolute_error(np.exp(y_test_xgb1), np.exp(y_log_pred_xgb1))

# %%
print("Mean Sqaure Error  : ", mseActual_xgb1)
print("r2 score           : ", r2Actual_xgb1)
print("Mean Absolute Error : ", maeActual_xgb1)
# Out:
# Mean Sqaure Error  :  4.6333090453332136e-17
# r2 score           :  0.7840626825476646
# Mean Absolute Error :  5.21891014610064e-09
